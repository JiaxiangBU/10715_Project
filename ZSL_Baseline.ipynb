# %%
# Load pretrained model, and generate new transformed dataset by passing images through pretrained model 
import os
import numpy as np
import pickle
import keras
import pandas as pd
from resnetV2 import *

from keras.datasets import cifar100
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model, load_model
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
data_dir = os.path.join(os.getcwd(), 'Data/cifar-100-python/')
train = pickle.load(open(os.path.join(data_dir, 'train'), "rb"), encoding='latin1')
test = pickle.load(open(os.path.join(data_dir, 'test'), "rb"), encoding='latin1')
meta = pickle.load(open(os.path.join(data_dir, 'meta'), "rb"), encoding='latin1')

# %%
num_fine = 100
num_coarse = 20

# %%
coarse_label_names = meta['coarse_label_names']
fine_label_names = meta['fine_label_names']

x_train = train['data'].reshape((-1, 32, 32, 3))
y_train_coarse = np.array(train['coarse_labels'])
y_train_fine = np.array(train['fine_labels'])

x_test = test['data'].reshape((-1, 32, 32, 3))
y_test_coarse = np.array(test['coarse_labels'])
y_test_fine = np.array(test['fine_labels'])

# %%
d = {'coarse': y_train_coarse, 'coarse_cat_name': [coarse_label_names[i] for i in y_train_coarse],
     'fine': y_train_fine, 'fine_cat_name': [fine_label_names[i] for i in y_train_fine]}
df_train = pd.DataFrame(data=d)

# %%
d = {'coarse': y_test_coarse, 'coarse_cat_name': [coarse_label_names[i] for i in y_test_coarse],
     'fine': y_test_fine, 'fine_cat_name': [fine_label_names[i] for i in y_test_fine]}
df_test = pd.DataFrame(data=d)

# %%
# dictionary that maps each coarse label to the set of fine labels

coarse_to_fine = {}
for i in range(num_coarse):
    coarse_to_fine[i] = np.unique(df_train[df_train['coarse'] == i]['fine'])
    
# print(coarse_to_fine)

# %%
# dictionary that maps each coarse label to the fine label that will be unseen in the training set

np.random.seed(seed=0)
unseen_labels_ix = np.random.randint(5, size=num_coarse)

coarse_to_unseen = {}
unseen_fine_labels = []
for i in range(num_coarse):
    coarse_to_unseen[i] = coarse_to_fine[i][unseen_labels_ix[i]]
    unseen_fine_labels.append(coarse_to_fine[i][unseen_labels_ix[i]])

# print(coarse_to_unseen)

# %%
# list of label names to exclude from training

[fine_label_names[i] for i in unseen_fine_labels]
# Out:
# ['whale',
#  'aquarium_fish',
#  'sunflower',
#  'cup',
#  'pear',
#  'keyboard',
#  'table',
#  'butterfly',
#  'wolf',
#  'bridge',
#  'cloud',
#  'kangaroo',
#  'possum',
#  'lobster',
#  'baby',
#  'dinosaur',
#  'mouse',
#  'maple_tree',
#  'bus',
#  'tractor']

# %%
df_train['Unseen'] = [label in unseen_fine_labels for label in y_train_fine]
df_test['Unseen'] = [label in unseen_fine_labels for label in y_test_fine]

# %%
df_train
# Out:
#        coarse                 coarse_cat_name  fine  fine_cat_name  Unseen
# 0          11  large_omnivores_and_herbivores    19         cattle   False
# 1          15                        reptiles    29       dinosaur    True
# 2           4            fruit_and_vegetables     0          apple   False
# 3          14                          people    11            boy   False
# 4           1                            fish     1  aquarium_fish    True
# 5           5    household_electrical_devices    86      telephone   False
# 6          18                      vehicles_1    90          train   False
# 7           3                 food_containers    28            cup    True
# 8          10    large_natural_outdoor_scenes    23          cloud    True
# 9          11  large_omnivores_and_herbivores    31       elephant   False
# 10          5    household_electrical_devices    39       keyboard    True
# 11         17                           trees    96    willow_tree   False
# 12          2                         flowers    82      sunflower    True
# 13          9   large_man-made_outdoor_things    17         castle   False
# 14         10    large_natural_outdoor_scenes    71            sea   False
# 15          5    household_electrical_devices    39       keyboard    True
# 16         18                      vehicles_1     8        bicycle   False
# 17          8                large_carnivores    97           wolf    True
# 18         16                   small_mammals    80       squirrel   False
# 19         10    large_natural_outdoor_scenes    71            sea   False
# 20         16                   small_mammals    74          shrew   False
# 21         17                           trees    59      pine_tree   False
# 22          2                         flowers    70           rose   False
# 23          5    household_electrical_devices    87     television   False
# 24         17                           trees    59      pine_tree   False
# 25          6             household_furniture    84          table    True
# 26         12                  medium_mammals    64         possum    True
# 27         17                           trees    52       oak_tree   False
# 28          8                large_carnivores    42        leopard   False
# 29         12                  medium_mammals    64         possum    True
# ...       ...                             ...   ...            ...     ...
# 49970      18                      vehicles_1    90          train   False
# 49971       1                            fish     1  aquarium_fish    True
# 49972      10    large_natural_outdoor_scenes    49       mountain   False
# 49973      12                  medium_mammals    34            fox   False
# 49974      11  large_omnivores_and_herbivores    19         cattle   False
# 49975      12                  medium_mammals    75          skunk   False
# 49976      14                          people     2           baby    True
# 49977       9   large_man-made_outdoor_things    12         bridge    True
# 49978      12                  medium_mammals    34            fox   False
# 49979      17                           trees    59      pine_tree   False
# 49980      17                           trees    96    willow_tree   False
# 49981       9   large_man-made_outdoor_things    12         bridge    True
# 49982       6             household_furniture    94       wardrobe   False
# 49983      19                      vehicles_2    89        tractor    True
# 49984      13        non-insect_invertebrates    45        lobster    True
# 49985      18                      vehicles_1    48     motorcycle   False
# 49986       6             household_furniture    20          chair   False
# 49987      12                  medium_mammals    34            fox   False
# 49988       5    household_electrical_devices    87     television   False
# 49989      12                  medium_mammals    64         possum    True
# 49990      13        non-insect_invertebrates    26           crab   False
# 49991       3                 food_containers    16            can   False
# 49992       4            fruit_and_vegetables    53         orange   False
# 49993      10    large_natural_outdoor_scenes    33         forest   False
# 49994       8                large_carnivores    97           wolf    True
# 49995      16                   small_mammals    80       squirrel   False
# 49996       7                         insects     7         beetle   False
# 49997       8                large_carnivores     3           bear   False
# 49998       7                         insects     7         beetle   False
# 49999       1                            fish    73          shark   False
#
# [50000 rows x 5 columns]

# %%
train_ix_unseen = df_train[df_train['Unseen']].index.values
train_ix_seen = df_train[~df_train['Unseen']].index.values
test_ix_unseen = df_test[df_test['Unseen']].index.values
test_ix_seen = df_test[~df_test['Unseen']].index.values

print('Unseen train:', len(train_ix_unseen))
print('Seen train:', len(train_ix_seen))
print('Unseen test:', len(test_ix_unseen))
print('Seen test:', len(test_ix_seen))
# Out:
# Unseen train: 10000
# Seen train: 40000
# Unseen test: 2000
# Seen test: 8000

# %% [markdown]
# ## Zero Shot Learning

# %%
# Train on 40000 "seen" train examples
X_train = x_train[train_ix_seen]
y_train = y_train_fine[train_ix_seen]
print ('Train:', len(X_train))

# Test on 8000 "seen" test examples
X_test_seen = x_test[test_ix_seen]
y_test_seen = y_test_fine[test_ix_seen]
print ('Test seen:', len(X_test_seen))

# Test on 12000 "unseen" train+test examples
X_test_unseen = np.concatenate([x_train[train_ix_unseen], x_test[test_ix_unseen]])
y_test_unseen = np.concatenate([y_train_fine[train_ix_unseen], y_test_fine[test_ix_unseen]])
print ('Test unseen:', len(X_test_unseen))

# Test on all 20000 examples left over (generalized ZSL)
X_test_all = np.concatenate([X_test_seen, X_test_unseen])
y_test_all = np.concatenate([y_test_seen, y_test_unseen])
print ('Test all:', len(X_test_all))

input_shape = X_train[0].shape
# Out:
# Train: 40000
# Test seen: 8000
# Test unseen: 12000
# Test all: 20000

# %%
def get_one_hot(y, num_classes):
    result = np.zeros((len(y), num_classes))
    result[(np.arange(len(y)), y)] = 1
    return result

y_train_oh = get_one_hot(y_train, num_fine)
y_test_seen_oh = get_one_hot(y_test_seen, num_fine)
y_test_unseen_oh = get_one_hot(y_test_unseen, num_fine)
y_test_all_oh = get_one_hot(y_test_all, num_fine)

# %%
# Training parameters
batch_size = 125
epochs = 150
num_classes = 100

data_augmentation = True
subtract_pixel_mean = True

# %%
# Model parameter (CIFAR-10)
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------

version = 2
n = 6

# %%
depth = n * 9 + 2
model_type = 'ResNet%dv%d' % (depth, version)

# %%
save_dir = os.path.join(os.getcwd(), 'saved_models/zsl/%s/baseline/' % model_type)
model_name = 'cifar100_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
model = resnet_v2(input_shape=input_shape, depth=depth)
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   272         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   1088        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   1088        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   1040        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   1088        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 16)   1040        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 16)   2320        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 16)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 64)   1088        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 64)   0           add_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 16)   1040        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 16)   64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 16)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32,
0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 256)    0           add_13[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8, 8, 256)    1024        add_14[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 8, 8, 256)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 128)    32896       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 8, 8, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 128)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 128)    147584      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 128)    512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 128)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 256)    33024       activation_45[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 256)    0           add_14[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 8, 8, 256)    1024        add_15[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 256)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 8, 128)    32896       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 8, 8, 128)    512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 8, 8, 128)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 128)    147584      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 8, 8, 128)    512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 8, 8, 128)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 256)    33024       activation_48[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 256)    0           add_15[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 8, 8, 256)    1024        add_16[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 8, 8, 256)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 128)    32896       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 8, 8, 128)    512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8, 8, 128)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 128)    147584      activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 8, 8, 128)    512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 128)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 256)    33024       activation_51[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           add_16[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 256)    1024        add_17[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 256)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 128)    32896       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 128)    512         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 128)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 128)    147584      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 128)    512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 128)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 256)    33024       activation_54[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 256)    0           add_17[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 256)    1024        add_18[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 256)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 256)    0           activation_55[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          25700       flatten_1[0][0]
# ==================================================================================================
# Total params: 1,696,868
# Trainable params: 1,686,468
# Non-trainable params: 10,400
# __________________________________________________________________________________________________

# %%
datagen = getImageDataGenerator(augment=data_augmentation)

# %%
history = model.fit_generator(datagen.flow(X_train, y_train_oh, batch_size=batch_size),
                              epochs=epochs, steps_per_epoch=x_train.shape[0] // batch_size,
                              validation_data=(X_test_seen, y_test_seen_oh),
                              verbose=1, workers=4, callbacks=callbacks)
# Out:
# Epoch 1/150
# Learning rate:  0.001
# 400/400 [==============================] - 54s 134ms/step - loss: 4.6012 - acc: 0.1149 - val_loss: 4.2209 - val_acc: 0.1504
#
# Epoch 00001: val_acc improved from -inf to 0.15037, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.001.h5
# Epoch 2/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 3.8404 - acc: 0.2036 - val_loss: 4.0366 - val_acc: 0.1521
#
# Epoch 00002: val_acc improved from 0.15037 to 0.15212, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.002.h5
# Epoch 3/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 3.4852 - acc: 0.2484 - val_loss: 3.7658 - val_acc: 0.1926
#
# Epoch 00003: val_acc improved from 0.15212 to 0.19263, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.003.h5
# Epoch 4/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 104ms/step - loss: 3.2632 - acc: 0.2842 - val_loss: 3.3332 - val_acc: 0.2703
#
# Epoch 00004: val_acc improved from 0.19263 to 0.27025, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.004.h5
# Epoch 5/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 3.0825 - acc: 0.3128 - val_loss: 3.4410 - val_acc: 0.2413
#
# Epoch 00005: val_acc did not improve from 0.27025
# Epoch 6/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.9662 - acc: 0.3313 - val_loss: 3.4496 - val_acc: 0.2518
#
# Epoch 00006: val_acc did not improve from 0.27025
# Epoch 7/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.8541 - acc: 0.3567 - val_loss: 3.0443 - val_acc: 0.3277
#
# Epoch 00007: val_acc improved from 0.27025 to 0.32775, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.007.h5
# Epoch 8/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.7722 - acc: 0.3722 - val_loss: 3.3164 - val_acc: 0.2784
#
# Epoch 00008: val_acc did not improve from 0.32775
# Epoch 9/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.6753 - acc: 0.3912 - val_loss: 3.2227 - val_acc: 0.3054
#
# Epoch 00009: val_acc did not improve from 0.32775
# Epoch 10/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.6176 - acc: 0.4017 - val_loss: 3.4371 - val_acc: 0.2663
#
# Epoch 00010: val_acc did not improve from 0.32775
# Epoch 11/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.5404 - acc: 0.4198 - val_loss: 2.8902 - val_acc: 0.3566
#
# Epoch 00011: val_acc improved from 0.32775 to 0.35662, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.011.h5
# Epoch 12/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.4820 - acc: 0.4333 - val_loss: 2.7722 - val_acc: 0.3776
#
# Epoch 00012: val_acc improved from 0.35662 to 0.37763, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.012.h5
# Epoch 13/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.4178 - acc: 0.4469 - val_loss: 2.7032 - val_acc: 0.3915
#
# Epoch 00013: val_acc improved from 0.37763 to 0.39150, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.013.h5
# Epoch 14/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.3733 - acc: 0.4564 - val_loss: 2.9611 - val_acc: 0.3601
#
# Epoch 00014: val_acc did not improve from 0.39150
# Epoch 15/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 105ms/step - loss: 2.3327 - acc: 0.4674 - val_loss: 2.6773 - val_acc: 0.4031
#
# Epoch 00015: val_acc improved from 0.39150 to 0.40313, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.015.h5
# Epoch 16/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.2945 - acc: 0.4765 - val_loss: 2.7008 - val_acc: 0.3976
#
# Epoch 00016: val_acc did not improve from 0.40313
# Epoch 17/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.2343 - acc: 0.4930 - val_loss: 2.6344 - val_acc: 0.4158
#
# Epoch 00017: val_acc improved from 0.40313 to 0.41575, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.017.h5
# Epoch 18/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.2068 - acc: 0.4959 - val_loss: 2.8751 - val_acc: 0.3810
#
# Epoch 00018: val_acc did not improve from 0.41575
# Epoch 19/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.1672 - acc: 0.5089 - val_loss: 2.9554 - val_acc: 0.3725
#
# Epoch 00019: val_acc did not improve from 0.41575
# Epoch 20/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.1359 - acc: 0.5139 - val_loss: 2.9830 - val_acc: 0.3690
#
# Epoch 00020: val_acc did not improve from 0.41575
# Epoch 21/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 104ms/step - loss: 2.0928 - acc: 0.5271 - val_loss: 2.5540 - val_acc: 0.4342
#
# Epoch 00021: val_acc improved from 0.41575 to 0.43425, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.021.h5
# Epoch 22/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.0702 - acc: 0.5312 - val_loss: 2.8223 - val_acc: 0.4082
#
# Epoch 00022: val_acc did not improve from 0.43425
# Epoch 23/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 104ms/step - loss: 2.0471 - acc: 0.5393 - val_loss: 2.7064 - val_acc: 0.4161
#
# Epoch 00023: val_acc did not improve from 0.43425
# Epoch 24/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 2.0169 - acc: 0.5471 - val_loss: 2.8967 - val_acc: 0.3890
#
# Epoch 00024: val_acc did not improve from 0.43425
# Epoch 25/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 104ms/step - loss: 1.9748 - acc: 0.5593 - val_loss: 2.8213 - val_acc: 0.4062
#
# Epoch 00025: val_acc did not improve from 0.43425
# Epoch 26/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 1.9528 - acc: 0.5643 - val_loss: 2.5900 - val_acc: 0.4440
#
# Epoch 00026: val_acc improved from 0.43425 to 0.44400, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.026.h5
# Epoch 27/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 1.9379 - acc: 0.5690 - val_loss: 2.7190 - val_acc: 0.4355
#
# Epoch 00027: val_acc did not improve from 0.44400
# Epoch 28/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 1.9177 - acc: 0.5766 - val_loss: 2.7375 - val_acc: 0.4298
#
# Epoch 00028: val_acc did not improve from 0.44400
# Epoch 29/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 1.8627 - acc: 0.5920 - val_loss: 2.7296 - val_acc: 0.4394
#
# Epoch 00029: val_acc did not improve from 0.44400
# Epoch 30/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 1.8615 - acc: 0.5911 - val_loss: 2.6469 - val_acc: 0.4375
#
# Epoch 00030: val_acc did not improve from 0.44400
# Epoch 31/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 104ms/step - loss: 1.8401 - acc: 0.5987 - val_loss: 2.7932 - val_acc: 0.4265
#
# Epoch 00031: val_acc did not improve from 0.44400
# Epoch 32/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 1.8312 - acc: 0.6016 - val_loss: 2.8770 - val_acc: 0.4106
# Epoch 00032: val_acc did not improve from 0.44400
# Epoch 33/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.7788 - acc: 0.6152 - val_loss: 2.6430 - val_acc: 0.4520
#
# Epoch 00033: val_acc improved from 0.44400 to 0.45200, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.033.h5
# Epoch 34/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 101ms/step - loss: 1.7602 - acc: 0.6189 - val_loss: 3.2010 - val_acc: 0.3744
#
# Epoch 00034: val_acc did not improve from 0.45200
# Epoch 35/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.7659 - acc: 0.6188 - val_loss: 2.7618 - val_acc: 0.4515
#
# Epoch 00035: val_acc did not improve from 0.45200
# Epoch 36/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.7447 - acc: 0.6269 - val_loss: 2.7335 - val_acc: 0.4403
#
# Epoch 00036: val_acc did not improve from 0.45200
# Epoch 37/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.7041 - acc: 0.6388 - val_loss: 2.8302 - val_acc: 0.4388
#
# Epoch 00037: val_acc did not improve from 0.45200
# Epoch 38/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.6949 - acc: 0.6413 - val_loss: 2.9706 - val_acc: 0.4240
#
# Epoch 00038: val_acc did not improve from 0.45200
# Epoch 39/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 105ms/step - loss: 1.6894 - acc: 0.6428 - val_loss: 2.6548 - val_acc: 0.4633
#
# Epoch 00039: val_acc improved from 0.45200 to 0.46325, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.039.h5
# Epoch 40/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 1.6744 - acc: 0.6470 - val_loss: 2.8766 - val_acc: 0.4339
#
# Epoch 00040: val_acc did not improve from 0.46325
# Epoch 41/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 1.6310 - acc: 0.6612 - val_loss: 2.9708 - val_acc: 0.4406
#
# Epoch 00041: val_acc did not improve from 0.46325
# Epoch 42/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 1.6237 - acc: 0.6644 - val_loss: 2.8132 - val_acc: 0.4595
#
# Epoch 00042: val_acc did not improve from 0.46325
# Epoch 43/150
# Learning rate:  0.001
# 400/400 [==============================] - 43s 106ms/step - loss: 1.6209 - acc: 0.6657 - val_loss: 2.8405 - val_acc: 0.4545
#
# Epoch 00043: val_acc did not improve from 0.46325
# Epoch 44/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.6046 - acc: 0.6708 - val_loss: 2.7862 - val_acc: 0.4640
#
# Epoch 00044: val_acc improved from 0.46325 to 0.46400, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.044.h5
# Epoch 45/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.5729 - acc: 0.6821 - val_loss: 2.7108 - val_acc: 0.4684
#
# Epoch 00045: val_acc improved from 0.46400 to 0.46838, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.045.h5
# Epoch 46/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.5660 - acc: 0.6830 - val_loss: 2.7741 - val_acc: 0.4573
#
# Epoch 00046: val_acc did not improve from 0.46838
# Epoch 47/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.5470 - acc: 0.6918 - val_loss: 2.9257 - val_acc: 0.4431
#
# Epoch 00047: val_acc did not improve from 0.46838
# Epoch 48/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.5566 - acc: 0.6874 - val_loss: 2.8418 - val_acc: 0.4631
#
# Epoch 00048: val_acc did not improve from 0.46838
# Epoch 49/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.5133 - acc: 0.6999 - val_loss: 2.8285 - val_acc: 0.4600
#
# Epoch 00049: val_acc did not improve from 0.46838
# Epoch 50/150
# Learning rate:  0.001
# 400/400 [==============================] - 42s 104ms/step - loss: 1.5122 - acc: 0.7023 - val_loss: 3.1168 - val_acc: 0.4409
#
# Epoch 00050: val_acc did not improve from 0.46838
# Epoch 51/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.5158 - acc: 0.7041 - val_loss: 3.0527 - val_acc: 0.4459
#
# Epoch 00051: val_acc did not improve from 0.46838
# Epoch 52/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.5005 - acc: 0.7074 - val_loss: 3.0867 - val_acc: 0.4303
#
# Epoch 00052: val_acc did not improve from 0.46838
# Epoch 53/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.4653 - acc: 0.7186 - val_loss: 3.0462 - val_acc: 0.4404
#
# Epoch 00053: val_acc did not improve from 0.46838
# Epoch 54/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.4649 - acc: 0.7201 - val_loss: 3.0751 - val_acc: 0.4518
#
# Epoch 00054: val_acc did not improve from 0.46838
# Epoch 55/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.4615 - acc: 0.7215 - val_loss: 3.0515 - val_acc: 0.4494
#
# Epoch 00055: val_acc did not improve from 0.46838
# Epoch 56/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 103ms/step - loss: 1.4661 - acc: 0.7201 - val_loss: 3.1777 - val_acc: 0.4426
#
# Epoch 00056: val_acc did not improve from 0.46838
# Epoch 57/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s
150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.3019 - acc: 0.7852 - val_loss: 3.6424 - val_acc: 0.4334
#
# Epoch 00075: val_acc did not improve from 0.48463
# Epoch 76/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.3063 - acc: 0.7832 - val_loss: 3.6382 - val_acc: 0.4334
#
# Epoch 00076: val_acc did not improve from 0.48463
# Epoch 77/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.2630 - acc: 0.7966 - val_loss: 3.7884 - val_acc: 0.4424
#
# Epoch 00077: val_acc did not improve from 0.48463
# Epoch 78/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.2766 - acc: 0.7946 - val_loss: 3.4805 - val_acc: 0.4574
#
# Epoch 00078: val_acc did not improve from 0.48463
# Epoch 79/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.2722 - acc: 0.7957 - val_loss: 3.4939 - val_acc: 0.4599
#
# Epoch 00079: val_acc did not improve from 0.48463
# Epoch 80/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.2815 - acc: 0.7937 - val_loss: 3.3888 - val_acc: 0.4631
#
# Epoch 00080: val_acc did not improve from 0.48463
# Epoch 81/150
# Learning rate:  0.001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.2440 - acc: 0.8040 - val_loss: 3.4371 - val_acc: 0.4674
#
# Epoch 00081: val_acc did not improve from 0.48463
# Epoch 82/150
# Learning rate:  0.0001
# 400/400 [==============================] - 41s 102ms/step - loss: 1.0088 - acc: 0.8874 - val_loss: 2.8588 - val_acc: 0.5368
#
# Epoch 00082: val_acc improved from 0.48463 to 0.53675, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.082.h5
# Epoch 83/150
# Learning rate:  0.0001
# 400/400 [==============================] - 41s 102ms/step - loss: 0.8923 - acc: 0.9280 - val_loss: 2.9162 - val_acc: 0.5356
#
# Epoch 00083: val_acc did not improve from 0.53675
# Epoch 84/150
# Learning rate:  0.0001
# 400/400 [==============================] - 41s 102ms/step - loss: 0.8552 - acc: 0.9380 - val_loss: 2.9296 - val_acc: 0.5396
#
# Epoch 00084: val_acc improved from 0.53675 to 0.53963, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.084.h5
# Epoch 85/150
# Learning rate:  0.0001
# 400/400 [==============================] - 41s 102ms/step - loss: 0.8248 - acc: 0.9449 - val_loss: 2.9652 - val_acc: 0.5354
#
# Epoch 00085: val_acc did not improve from 0.53963
# Epoch 86/150
# Learning rate:  0.0001
# 400/400 [==============================] - 41s 102ms/step - loss: 0.8008 - acc: 0.9514 - val_loss: 2.9895 - val_acc: 0.5375
#
# Epoch 00086: val_acc did not improve from 0.53963
# Epoch 87/150
# Learning rate:  0.0001
# 400/400 [==============================] - 41s 102ms/step - loss: 0.7853 - acc: 0.9547 - val_loss: 3.0068 - val_acc: 0.5356
#
# Epoch 00087: val_acc did not improve from 0.53963
# Epoch 88/150
# Learning rate:  0.0001
# 400/400 [==============================] - 41s 102ms/step - loss: 0.7652 - acc: 0.9588 - val_loss: 3.0408 - val_acc: 0.5374
#
# Epoch 00088: val_acc did not improve from 0.53963
# Epoch 89/150
# Learning rate:  0.0001
# 400/400 [==============================] - 41s 102ms/step - loss: 0.7472 - acc: 0.9620 - val_loss: 3.0523 - val_acc: 0.5353
#
# Epoch 00089: val_acc did not improve from 0.53963
# Epoch 90/150
# Learning rate:  0.0001
# 400/400 [==============================] - 41s 102ms/step - loss: 0.7354 - acc: 0.9628 - val_loss: 3.0675 - val_acc: 0.5408
#
# Epoch 00090: val_acc improved from 0.53963 to 0.54075, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/zsl/ResNet56v2/baseline/cifar100_ResNet56v2_model.090.h5
# Epoch 91/150
# Learning rate:  0.0001
# 400/400 [==============================] - 41s
# Epoch 139/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4535 - acc: 0.9944 - val_loss: 3.4230 - val_acc: 0.5359
#
# Epoch 00139: val_acc did not improve from 0.54175
# Epoch 140/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4527 - acc: 0.9943 - val_loss: 3.4323 - val_acc: 0.5369
#
# Epoch 00140: val_acc did not improve from 0.54175
# Epoch 141/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4503 - acc: 0.9949 - val_loss: 3.4278 - val_acc: 0.5374
#
# Epoch 00141: val_acc did not improve from 0.54175
# Epoch 142/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4505 - acc: 0.9950 - val_loss: 3.4345 - val_acc: 0.5369
#
# Epoch 00142: val_acc did not improve from 0.54175
# Epoch 143/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4504 - acc: 0.9948 - val_loss: 3.4353 - val_acc: 0.5368
#
# Epoch 00143: val_acc did not improve from 0.54175
# Epoch 144/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4481 - acc: 0.9948 - val_loss: 3.4333 - val_acc: 0.5380
#
# Epoch 00144: val_acc did not improve from 0.54175
# Epoch 145/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4488 - acc: 0.9947 - val_loss: 3.4290 - val_acc: 0.5365
#
# Epoch 00145: val_acc did not improve from 0.54175
# Epoch 146/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4469 - acc: 0.9953 - val_loss: 3.4355 - val_acc: 0.5356
#
# Epoch 00146: val_acc did not improve from 0.54175
# Epoch 147/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4470 - acc: 0.9946 - val_loss: 3.4325 - val_acc: 0.5375
#
# Epoch 00147: val_acc did not improve from 0.54175
# Epoch 148/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4446 - acc: 0.9956 - val_loss: 3.4406 - val_acc: 0.5375
#
# Epoch 00148: val_acc did not improve from 0.54175
# Epoch 149/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4448 - acc: 0.9950 - val_loss: 3.4396 - val_acc: 0.5363
#
# Epoch 00149: val_acc did not improve from 0.54175
# Epoch 150/150
# Learning rate:  1e-05
# 400/400 [==============================] - 41s 102ms/step - loss: 0.4442 - acc: 0.9952 - val_loss: 3.4424 - val_acc: 0.5399
#
# Epoch 00150: val_acc did not improve from 0.54175

# %%
best_model_filepath = os.path.join(save_dir, 'cifar100_%s_model.%03d.h5' % (model_type, 82))
best_model = load_model(best_model_filepath)

# %%
def top_k_acc(y_pred, y_true, k=5):
    top_k = y_pred.argsort()[:, -k:]
    num_correct = 0
    for i in range(len(top_k)):
        if y_true[i] in top_k[i]:
            num_correct += 1
    
    return num_correct * 1.0 / len(top_k)

# %%
scores = best_model.evaluate(X_test_seen, y_test_seen_oh, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

y_test_seen_pred = best_model.predict(X_test_seen)
print('Top 5 accuracy:', top_k_acc(y_test_seen_pred, y_test_seen))
# Out:
# 8000/8000 [==============================] - 5s 612us/step
# Test loss: 2.8588431401252747
# Test accuracy: 0.53675
# Top 5 accuracy: 0.811

# %%
scores = best_model.evaluate(X_test_unseen, y_test_unseen_oh, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

y_test_unseen_pred = best_model.predict(X_test_unseen)
print('Top 5 accuracy:', top_k_acc(y_test_unseen_pred, y_test_unseen))
# Out:
# 12000/12000 [==============================] - 5s 425us/step
# Test loss: 16.75167812093099
# Test accuracy: 0.0
# Top 5 accuracy: 0.0

# %%
scores = best_model.evaluate(X_test_all, y_test_all_oh, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

y_test_all_pred = best_model.predict(X_test_all)
print('Top 5 accuracy:', top_k_acc(y_test_all_pred, y_test_all))
# Out:
# 20000/20000 [==============================] - 8s 423us/step
# Test loss: 11.194544128608703
# Test accuracy: 0.2147
# Top 5 accuracy: 0.3244

# %%
# Regular ZSL setting where we only need to consider choose between the 20 unseen classes, rather than all 100

y_test_unseen_pred = best_model.predict(X_test_unseen)
for i in range (100):
    if i not in unseen_fine_labels:
        y_test_unseen_pred[:, i] = -1
        
print('ZSL Test accuracy: ', np.mean(np.argmax(y_test_unseen_pred, axis=1) == y_test_unseen)) # 5%, pretty much random
print('Top 5 accuracy:', top_k_acc(y_test_unseen_pred, y_test_unseen))
# Out:
# ZSL Test accuracy:  0.0395
# Top 5 accuracy: 0.23358333333333334

# %% [markdown]
# ## Extract Features

# %%
print("Extracting layer: %s" % (best_model.get_layer(index=-6).name))
feat_extractor_model = Model(inputs= best_model.input, outputs = best_model.get_layer(index=-6).output)
# Out:
# Extracting layer: add_18

# %%
X_train_feat = feat_extractor_model.predict(X_train)
X_test_seen_feat = feat_extractor_model.predict(X_test_seen)
X_test_unseen_feat = feat_extractor_model.predict(X_test_unseen)
X_test_all_feat = feat_extractor_model.predict(X_test_all)

input_shape = X_train_feat[0].shape

# %%
save_dir_feat = os.path.join(os.getcwd(), 'saved_models/zsl/%s/extracted_feat/' % (model_type))
if not os.path.isdir(save_dir_feat):
    os.makedirs(save_dir_feat)

# %%
# Save X feature arrays
np.save(os.path.join(save_dir_feat, 'X_train_feat_cifar100_%s.npy' % (model_type)), X_train_feat)
np.save(os.path.join(save_dir_feat, 'X_test_seen_feat_cifar100_%s.npy' % (model_type)), X_test_seen_feat)
np.save(os.path.join(save_dir_feat, 'X_test_unseen_feat_cifar100_%s.npy' % (model_type)), X_test_unseen_feat)
np.save(os.path.join(save_dir_feat, 'X_test_all_feat_cifar100_%s.npy' % (model_type)), X_test_all_feat)

# %%
# Save y arrays
np.save(os.path.join(save_dir_feat, 'y_train_cifar100_%s.npy' % (model_type)), y_train)
np.save(os.path.join(save_dir_feat, 'y_test_seen_cifar100_%s.npy' % (model_type)), y_test_seen)
np.save(os.path.join(save_dir_feat, 'y_test_unseen_cifar100_%s.npy' % (model_type)), y_test_unseen)
np.save(os.path.join(save_dir_feat, 'y_test_all_cifar100_%s.npy' % (model_type)), y_test_all)
