# %%
import os
import numpy as np
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Dense, BatchNormalization, Activation, AveragePooling2D, Flatten
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.datasets import cifar100
from keras import backend as K
import pickle
import sklearn
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
model_type = 'ResNet56v2'

# %%
#Loading data and embeddings
label_embeddings = pickle.load(open("Data/Embeddings/CIFAR/CIFAR_100_label_to_embedding_google_news.pk", "rb"))
embedding_len = len(label_embeddings[0])

save_dir_feat = os.path.join(os.getcwd(), 'saved_models/%s/extracted_feat/' % (model_type))
x_train = np.load(os.path.join(save_dir_feat, 'x_train_feat_cifar100_%s.npy' % (model_type)))
x_test = np.load(os.path.join(save_dir_feat, 'x_test_feat_cifar100_%s.npy' % (model_type)))
input_shape = x_train[0].shape

y_train = cifar100.load_data()[0][1]
y_test = cifar100.load_data()[1][1]

# %%
#Convert train/test labels to embeddings
y_train_embeddings = np.zeros((50000, embedding_len))
y_test_embeddings = np.zeros((10000, embedding_len))

for i in range(y_train.shape[0]):
    y_train_embeddings[i] = label_embeddings[int(y_train[i][0])]

for i in range(y_test.shape[0]):
    y_test_embeddings[i] = label_embeddings[int(y_test[i][0])]

label_embeddings_arr = np.zeros((100, embedding_len))
for i in range(100):
    label_embeddings_arr[i] = label_embeddings[i]

# %%
def build_model(input_shape=input_shape, embedding_len=embedding_len):
    inputs = Input(shape=input_shape)

    x = BatchNormalization()(inputs)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=2)(x)
    
    x = Flatten()(x)
    
    x = Dense(1024) (x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    x = Dense(512) (x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    x = Dense(embedding_len) (x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    
    outputs = Dense(embedding_len,
                    kernel_initializer='he_normal')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
batch_size = 128
epochs = 100

# %%
model = build_model()
model.compile(loss='cosine_proximity', optimizer='adam', metrics=['mse'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              4195328
# _________________________________________________________________
# activation_2 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_3 (Dense)              (None, 300)               153900
# _________________________________________________________________
# activation_4 (Activation)    (None, 300)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 300)               1200
# _________________________________________________________________
# dense_4 (Dense)              (None, 300)               90300
# =================================================================
# Total params: 4,972,696
# Trainable params: 4,968,512
# Non-trainable params: 4,184
# _________________________________________________________________

# %%
save_dir = os.path.join(os.getcwd(), 'saved_models/%s/w2v_transfer/' % (model_type))
model_name = 'cifar100_%s_w2v_transfer_model.{epoch:03d}.h5' % (model_type)
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer]

# %%
model.fit(x_train, y_train_embeddings,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test_embeddings),
          shuffle=True,
          callbacks=callbacks,
          verbose=1
         )
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 8s 154us/step - loss: -0.7387 - mean_squared_error: 2.9640 - val_loss: -0.7584 - val_mean_squared_error: 3.3311
#
# Epoch 00001: val_loss improved from inf to -0.75835, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.001.h5
# Epoch 2/100
# 50000/50000 [==============================] - 6s 121us/step - loss: -0.9266 - mean_squared_error: 3.5278 - val_loss: -0.7928 - val_mean_squared_error: 4.3469
#
# Epoch 00002: val_loss improved from -0.75835 to -0.79275, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.002.h5
# Epoch 3/100
# 50000/50000 [==============================] - 6s 121us/step - loss: -0.9622 - mean_squared_error: 4.2081 - val_loss: -0.8003 - val_mean_squared_error: 4.6297
#
# Epoch 00003: val_loss improved from -0.79275 to -0.80032, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.003.h5
# Epoch 4/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9748 - mean_squared_error: 4.7357 - val_loss: -0.8072 - val_mean_squared_error: 4.6557
#
# Epoch 00004: val_loss improved from -0.80032 to -0.80720, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.004.h5
# Epoch 5/100
# 50000/50000 [==============================] - 6s 127us/step - loss: -0.9803 - mean_squared_error: 5.1623 - val_loss: -0.8008 - val_mean_squared_error: 5.1549
#
# Epoch 00005: val_loss did not improve from -0.80720
# Epoch 6/100
# 50000/50000 [==============================] - 7s 131us/step - loss: -0.9831 - mean_squared_error: 5.5417 - val_loss: -0.8064 - val_mean_squared_error: 5.1833
#
# Epoch 00006: val_loss did not improve from -0.80720
# Epoch 7/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9841 - mean_squared_error: 5.9216 - val_loss: -0.8010 - val_mean_squared_error: 5.3724
#
# Epoch 00007: val_loss did not improve from -0.80720
# Epoch 8/100
# 50000/50000 [==============================] - 6s 126us/step - loss: -0.9863 - mean_squared_error: 6.2703 - val_loss: -0.8010 - val_mean_squared_error: 5.3084
#
# Epoch 00008: val_loss did not improve from -0.80720
# Epoch 9/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9872 - mean_squared_error: 6.5928 - val_loss: -0.8062 - val_mean_squared_error: 5.2735
#
# Epoch 00009: val_loss did not improve from -0.80720
# Epoch 10/100
# 50000/50000 [==============================] - 6s 126us/step - loss: -0.9917 - mean_squared_error: 6.7627 - val_loss: -0.8189 - val_mean_squared_error: 5.9782
#
# Epoch 00010: val_loss improved from -0.80720 to -0.81892, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.010.h5
# Epoch 11/100
# 50000/50000 [==============================] - 6s 126us/step - loss: -0.9931 - mean_squared_error: 6.7890 - val_loss: -0.8186 - val_mean_squared_error: 5.8609
#
# Epoch 00011: val_loss did not improve from -0.81892
# Epoch 12/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9937 - mean_squared_error: 6.8134 - val_loss: -0.8198 - val_mean_squared_error: 5.7277
#
# Epoch 00012: val_loss improved from -0.81892 to -0.81984, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.012.h5
# Epoch 13/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9941 - mean_squared_error: 6.8386 - val_loss: -0.8201 - val_mean_squared_error: 5.7592
#
# Epoch 00013: val_loss improved from -0.81984 to -0.82005, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.013.h5
# Epoch 14/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9943 - mean_squared_error: 6.8646 - val_loss: -0.8212 - val_mean_squared_error: 5.5725
#
# Epoch 00014: val_loss improved from -0.82005 to -0.82119, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.014.h5
# Epoch 15/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9945 - mean_squared_error: 6.8930 - val_loss: -0.8210 - val_mean_squared_error: 5.8043
#
# Epoch 00015: val_loss did not improve from -0.82119
# Epoch 16/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9946 - mean_squared_error: 6.9219 - val_loss: -0.8211 - val_mean_squared_error: 5.7279
#
# Epoch 00016: val_loss did not improve from -0.82119
# Epoch 17/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9947 - mean_squared_error: 6.9599 - val_loss: -0.8204 - val_mean_squared_error: 5.5746
#
# Epoch 00017: val_loss did not improve from -0.82119
# Epoch 18/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9949 - mean_squared_error: 7.0042 - val_loss: -0.8203 - val_mean_squared_error: 5.6760
#
# Epoch 00018: val_loss did not improve from -0.82119
# Epoch 19/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9950 - mean_squared_error: 7.0395 - val_loss: -0.8223 - val_mean_squared_error: 5.6570
#
# Epoch 00019: val_loss improved from -0.82119 to -0.82235, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.019.h5
# Epoch 20/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9950 - mean_squared_error: 7.0818 - val_loss: -0.8216 - val_mean_squared_error: 5.7878
#
# Epoch 00020: val_loss did not improve from -0.82235
# Epoch 21/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9951 - mean_squared_error: 7.1275 - val_loss: -0.8204 - val_mean_squared_error: 5.7087
#
# Epoch 00021: val_loss did not improve from -0.82235
# Epoch 22/100
# 50000/50000 [==============================] - 6s 129us/step - loss: -0.9950 - mean_squared_error: 7.1682 - val_loss: -0.8188 - val_mean_squared_error: 6.1257
#
# Epoch 00022: val_loss did not improve from -0.82235
# Epoch 23/100
# 50000/50000 [==============================] - 6s 127us/step - loss: -0.9951 - mean_squared_error: 7.2204 - val_loss: -0.8182 - val_mean_squared_error: 5.7454
#
# Epoch 00023: val_loss did not improve from -0.82235
# Epoch 24/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9952 - mean_squared_error: 7.2719 - val_loss: -0.8190 - val_mean_squared_error: 5.9106
#
# Epoch 00024: val_loss did not improve from -0.82235
# Epoch 25/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9956 - mean_squared_error: 7.2944 - val_loss: -0.8223 - val_mean_squared_error: 5.9917
#
# Epoch 00025: val_loss did not improve from -0.82235
# Epoch 26/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9959 - mean_squared_error: 7.2939 - val_loss: -0.8230 - val_mean_squared_error: 5.9702
#
# Epoch 00026: val_loss improved from -0.82235 to -0.82305, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.026.h5
# Epoch 27/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9960 - mean_squared_error: 7.2916 - val_loss: -0.8231 - val_mean_squared_error: 5.8578
#
# Epoch 00027: val_loss improved from -0.82305 to -0.82310, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.027.h5
# Epoch 28/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9961 - mean_squared_error: 7.2922 - val_loss: -0.8227 - val_mean_squared_error: 5.8651
#
# Epoch 00028: val_loss did not improve from -0.82310
# Epoch 29/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9960 - mean_squared_error: 7.2898 - val_loss: -0.8237 - val_mean_squared_error: 5.9340
#
# Epoch 00029: val_loss improved from -0.82310 to -0.82368, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.029.h5
# Epoch 30/100
# 50000/50000 [==============================] - 6s 120us/step - loss: -0.9960 - mean_squared_error: 7.2930 - val_loss: -0.8239 - val_mean_squared_error: 5.9474
#
# Epoch 00030: val_loss improved from -0.82368 to -0.82388, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.030.h5
# Epoch 31/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9962 - mean_squared_error: 7.2933 - val_loss: -0.8243 - val_mean_squared_error: 5.8430
#
# Epoch 00031: val_loss improved from -0.82388 to -0.82433, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.031.h5
# Epoch 32/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9962 - mean_squared_error: 7.2956 - val_loss: -0.8230 - val_mean_squared_error: 5.8251
#
# Epoch 00032: val_loss did not improve from -0.82433
# Epoch 33/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9961 - mean_squared_error: 7.3014 - val_loss: -0.8226 - val_mean_squared_error: 5.9186
#
# Epoch 00033: val_loss did not improve from -0.82433
# Epoch 34/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9962 - mean_squared_error: 7.3035 - val_loss: -0.8240 - val_mean_squared_error: 5.8596
#
# Epoch 00034: val_loss did not improve from -0.82433
# Epoch 35/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9963 - mean_squared_error: 7.3037 - val_loss: -0.8244 - val_mean_squared_error: 5.8605
#
# Epoch 00035: val_loss improved from -0.82433 to -0.82438, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.035.h5
# Epoch 36/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9963 - mean_squared_error: 7.3004 - val_loss: -0.8239 - val_mean_squared_error: 5.8695
#
# Epoch 00036: val_loss did not improve from -0.82438
# Epoch 37/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9963 - mean_squared_error: 7.3051 - val_loss: -0.8241 - val_mean_squared_error: 5.9053
#
# Epoch 00037: val_loss did not improve from -0.82438
# Epoch 38/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9964 - mean_squared_error: 7.3010 - val_loss: -0.8244 - val_mean_squared_error: 5.9057
#
# Epoch 00038: val_loss improved from -0.82438 to -0.82443, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.038.h5
# Epoch 39/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9965 - mean_squared_error: 7.2992 - val_loss: -0.8246 - val_mean_squared_error: 5.8699
#
# Epoch 00039: val_loss improved from -0.82443 to -0.82461, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.039.h5
# Epoch 40/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9964 - mean_squared_error: 7.2989 - val_loss: -0.8247 - val_mean_squared_error: 5.8850
#
# Epoch 00040: val_loss improved from -0.82461 to -0.82470, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.040.h5
# Epoch 41/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9964 - mean_squared_error: 7.3001 - val_loss: -0.8247 - val_mean_squared_error: 5.8532
#
# Epoch 00041: val_loss improved from -0.82470 to -0.82471, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.041.h5
# Epoch 42/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9965 - mean_squared_error: 7.2991 - val_loss: -0.8250 - val_mean_squared_error: 5.8325
#
# Epoch 00042: val_loss improved from -0.82471 to -0.82497, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.042.h5
# Epoch 43/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9965 - mean_squared_error: 7.2992 - val_loss: -0.8246 - val_mean_squared_error: 5.8138
#
# Epoch 00043: val_loss did not improve from -0.82497
# Epoch 44/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9964 - mean_squared_error: 7.2997 - val_loss: -0.8249 - val_mean_squared_error: 5.7763
#
# Epoch 00044: val_loss did not improve from -0.82497
# Epoch 45/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9965 - mean_squared_error: 7.2948 - val_loss: -0.8249 - val_mean_squared_error: 5.8091
#
# Epoch 00045: val_loss did not improve from -0.82497
# Epoch 46/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9965 - mean_squared_error: 7.2943 - val_loss: -0.8247 - val_mean_squared_error: 5.8342
#
# Epoch 00046: val_loss did not improve from -0.82497
# Epoch 47/100
# 50000/50000 [==============================] - 6s 126us/step - loss: -0.9965 - mean_squared_error: 7.2935 - val_loss: -0.8245 - val_mean_squared_error: 5.8088
#
# Epoch 00047: val_loss did not improve from -0.82497
# Epoch 48/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2916 - val_loss: -0.8247 - val_mean_squared_error: 5.8091
#
# Epoch 00048: val_loss did not improve from -0.82497
# Epoch 49/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9966 - mean_squared_error: 7.2912 - val_loss: -0.8248 - val_mean_squared_error: 5.8075
#
# Epoch 00049: val_loss did not improve from -0.82497
# Epoch 50/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9965 - mean_squared_error: 7.2918 - val_loss: -0.8247 - val_mean_squared_error: 5.8290
#
# Epoch 00050: val_loss did not improve from -0.82497
# Epoch 51/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9965 - mean_squared_error: 7.2889 - val_loss: -0.8250 - val_mean_squared_error: 5.7982
#
# Epoch 00051: val_loss improved from -0.82497 to -0.82498, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.051.h5
# Epoch 52/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9965 - mean_squared_error: 7.2904 - val_loss: -0.8250 - val_mean_squared_error: 5.8444
#
# Epoch 00052: val_loss improved from -0.82498 to -0.82501, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.052.h5
# Epoch 53/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9966 - mean_squared_error: 7.2921 - val_loss: -0.8249 - val_mean_squared_error: 5.8225
#
# Epoch 00053: val_loss did not improve from -0.82501
# Epoch 54/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9965 - mean_squared_error: 7.2900 - val_loss: -0.8249 - val_mean_squared_error: 5.7974
#
# Epoch 00054: val_loss did not improve from -0.82501
# Epoch 55/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9966 - mean_squared_error: 7.2924 - val_loss: -0.8251 - val_mean_squared_error: 5.8052
#
# Epoch 00055: val_loss improved from -0.82501 to -0.82506, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.055.h5
# Epoch 56/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9965 - mean_squared_error: 7.2928 - val_loss: -0.8251 - val_mean_squared_error: 5.8498
#
# Epoch 00056: val_loss improved from -0.82506 to -0.82507, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.056.h5
# Epoch 57/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9965 - mean_squared_error: 7.2907 - val_loss: -0.8248 - val_mean_squared_error: 5.8570
#
# Epoch 00057: val_loss did not improve from -0.82507
# Epoch 58/100
# 50000/50000 [==============================] - 6s 121us/step - loss: -0.9965 - mean_squared_error: 7.2918 - val_loss: -0.8250 - val_mean_squared_error: 5.8225
# Epoch 00058: val_loss did not improve from -0.82507
# Epoch 59/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2917 - val_loss: -0.8252 - val_mean_squared_error: 5.7793
#
# Epoch 00059: val_loss improved from -0.82507 to -0.82515, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.059.h5
# Epoch 60/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9966 - mean_squared_error: 7.2921 - val_loss: -0.8251 - val_mean_squared_error: 5.8243
#
# Epoch 00060: val_loss did not improve from -0.82515
# Epoch 61/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9966 - mean_squared_error: 7.2915 - val_loss: -0.8251 - val_mean_squared_error: 5.7561
#
# Epoch 00061: val_loss did not improve from -0.82515
# Epoch 62/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9966 - mean_squared_error: 7.2904 - val_loss: -0.8249 - val_mean_squared_error: 5.7750
#
# Epoch 00062: val_loss did not improve from -0.82515
# Epoch 63/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2901 - val_loss: -0.8252 - val_mean_squared_error: 5.7776
#
# Epoch 00063: val_loss improved from -0.82515 to -0.82517, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.063.h5
# Epoch 64/100
# 50000/50000 [==============================] - 7s 143us/step - loss: -0.9966 - mean_squared_error: 7.2914 - val_loss: -0.8250 - val_mean_squared_error: 5.8279
#
# Epoch 00064: val_loss did not improve from -0.82517
# Epoch 65/100
# 50000/50000 [==============================] - 8s 162us/step - loss: -0.9966 - mean_squared_error: 7.2913 - val_loss: -0.8251 - val_mean_squared_error: 5.7647
#
# Epoch 00065: val_loss did not improve from -0.82517
# Epoch 66/100
# 50000/50000 [==============================] - 8s 152us/step - loss: -0.9966 - mean_squared_error: 7.2903 - val_loss: -0.8252 - val_mean_squared_error: 5.8085
#
# Epoch 00066: val_loss improved from -0.82517 to -0.82520, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.066.h5
# Epoch 67/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2919 - val_loss: -0.8251 - val_mean_squared_error: 5.8234
#
# Epoch 00067: val_loss did not improve from -0.82520
# Epoch 68/100
# 50000/50000 [==============================] - 6s 122us/step - loss: -0.9966 - mean_squared_error: 7.2914 - val_loss: -0.8250 - val_mean_squared_error: 5.7680
#
# Epoch 00068: val_loss did not improve from -0.82520
# Epoch 69/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2915 - val_loss: -0.8249 - val_mean_squared_error: 5.8017
#
# Epoch 00069: val_loss did not improve from -0.82520
# Epoch 70/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9965 - mean_squared_error: 7.2881 - val_loss: -0.8251 - val_mean_squared_error: 5.8494
#
# Epoch 00070: val_loss did not improve from -0.82520
# Epoch 71/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2913 - val_loss: -0.8250 - val_mean_squared_error: 5.8398
#
# Epoch 00071: val_loss did not improve from -0.82520
# Epoch 72/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9967 - mean_squared_error: 7.2891 - val_loss: -0.8250 - val_mean_squared_error: 5.7711
#
# Epoch 00072: val_loss did not improve from -0.82520
# Epoch 73/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2926 - val_loss: -0.8252 - val_mean_squared_error: 5.7957
#
# Epoch 00073: val_loss did not improve from -0.82520
# Epoch 74/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9966 - mean_squared_error: 7.2905 - val_loss: -0.8252 - val_mean_squared_error: 5.8180
#
# Epoch 00074: val_loss did not improve from -0.82520
# Epoch 75/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9966 - mean_squared_error: 7.2911 - val_loss: -0.8251 - val_mean_squared_error: 5.8075
#
# Epoch 00075: val_loss did not improve from -0.82520
# Epoch 76/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9966 - mean_squared_error: 7.2899 - val_loss: -0.8253 - val_mean_squared_error: 5.8273
#
# Epoch 00076: val_loss improved from -0.82520 to -0.82526, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.076.h5
# Epoch 77/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9965 - mean_squared_error: 7.2907 - val_loss: -0.8252 - val_mean_squared_error: 5.8027
#
# Epoch 00077: val_loss did not improve from -0.82526
# Epoch 78/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9965 - mean_squared_error: 7.2879 - val_loss: -0.8252 - val_mean_squared_error: 5.7871
#
# Epoch 00078: val_loss did not improve from -0.82526
# Epoch 79/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9966 - mean_squared_error: 7.2900 - val_loss: -0.8250 - val_mean_squared_error: 5.8258
#
# Epoch 00079: val_loss did not improve from -0.82526
# Epoch 80/100
# 50000/50000 [==============================] - 6s 126us/step - loss: -0.9966 - mean_squared_error: 7.2893 - val_loss: -0.8251 - val_mean_squared_error: 5.8296
#
# Epoch 00080: val_loss did not improve from -0.82526
# Epoch 81/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9966 - mean_squared_error: 7.2892 - val_loss: -0.8250 - val_mean_squared_error: 5.8050
#
# Epoch 00081: val_loss did not improve from -0.82526
# Epoch 82/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9966 - mean_squared_error: 7.2881 - val_loss: -0.8251 - val_mean_squared_error: 5.7889
#
# Epoch 00082: val_loss did not improve from -0.82526
# Epoch 83/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9965 - mean_squared_error: 7.2883 - val_loss: -0.8250 - val_mean_squared_error: 5.8027
#
# Epoch 00083: val_loss did not improve from -0.82526
# Epoch 84/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2893 - val_loss: -0.8250 - val_mean_squared_error: 5.7818
#
# Epoch 00084: val_loss did not improve from -0.82526
# Epoch 85/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2906 - val_loss: -0.8252 - val_mean_squared_error: 5.7639
#
# Epoch 00085: val_loss did not improve from -0.82526
# Epoch 86/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2883 - val_loss: -0.8252 - val_mean_squared_error: 5.7710
#
# Epoch 00086: val_loss did not improve from -0.82526
# Epoch 87/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9966 - mean_squared_error: 7.2884 - val_loss: -0.8251 - val_mean_squared_error: 5.7913
#
# Epoch 00087: val_loss did not improve from -0.82526
# Epoch 88/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9965 - mean_squared_error: 7.2880 - val_loss: -0.8251 - val_mean_squared_error: 5.8549
#
# Epoch 00088: val_loss did not improve from -0.82526
# Epoch 89/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2899 - val_loss: -0.8251 - val_mean_squared_error: 5.7817
#
# Epoch 00089: val_loss did not improve from -0.82526
# Epoch 90/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2923 - val_loss: -0.8250 - val_mean_squared_error: 5.8117
#
# Epoch 00090: val_loss did not improve from -0.82526
# Epoch 91/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2880 - val_loss: -0.8251 - val_mean_squared_error: 5.7373
#
# Epoch 00091: val_loss did not improve from -0.82526
# Epoch 92/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9965 - mean_squared_error: 7.2904 - val_loss: -0.8250 - val_mean_squared_error: 5.8048
# Epoch 00092: val_loss did not improve from -0.82526
# Epoch 93/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9966 - mean_squared_error: 7.2893 - val_loss: -0.8249 - val_mean_squared_error: 5.7977
#
# Epoch 00093: val_loss did not improve from -0.82526
# Epoch 94/100
# 50000/50000 [==============================] - 6s 126us/step - loss: -0.9965 - mean_squared_error: 7.2907 - val_loss: -0.8249 - val_mean_squared_error: 5.8022
#
# Epoch 00094: val_loss did not improve from -0.82526
# Epoch 95/100
# 50000/50000 [==============================] - 6s 124us/step - loss: -0.9965 - mean_squared_error: 7.2893 - val_loss: -0.8251 - val_mean_squared_error: 5.8057
#
# Epoch 00095: val_loss did not improve from -0.82526
# Epoch 96/100
# 50000/50000 [==============================] - 6s 123us/step - loss: -0.9967 - mean_squared_error: 7.2878 - val_loss: -0.8252 - val_mean_squared_error: 5.7694
#
# Epoch 00096: val_loss did not improve from -0.82526
# Epoch 97/100
# 50000/50000 [==============================] - 6s 126us/step - loss: -0.9966 - mean_squared_error: 7.2886 - val_loss: -0.8253 - val_mean_squared_error: 5.8214
#
# Epoch 00097: val_loss improved from -0.82526 to -0.82532, saving model to /home/tliu/Dev/CMU/10-715/10715_Project/saved_models/ResNet56v2/w2v_transfer/cifar100_ResNet56v2_w2v_transfer_model.097.h5
# Epoch 98/100
# 50000/50000 [==============================] - 6s 126us/step - loss: -0.9965 - mean_squared_error: 7.2899 - val_loss: -0.8251 - val_mean_squared_error: 5.8655
#
# Epoch 00098: val_loss did not improve from -0.82532
# Epoch 99/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9965 - mean_squared_error: 7.2890 - val_loss: -0.8252 - val_mean_squared_error: 5.7962
#
# Epoch 00099: val_loss did not improve from -0.82532
# Epoch 100/100
# 50000/50000 [==============================] - 6s 125us/step - loss: -0.9965 - mean_squared_error: 7.2893 - val_loss: -0.8252 - val_mean_squared_error: 5.8458
#
# Epoch 00100: val_loss did not improve from -0.82532

# %%
#Top K Predictions
def pred_top_k(y_test_pred, label_embeddings_arr=label_embeddings_arr, k=5):
    sim_table = cosine_similarity(y_test_pred, label_embeddings_arr)
    top_k_guesses = np.argpartition(sim_table,range(99-k+1,100),axis=1)[:,99-k+1:]
    return sim_table, top_k_guesses

#Top k Accuracy
def calc_top_k_acc(top_k, y_test):
    correct = 0
    for i in range(y_test.shape[0]):
        if np.squeeze(y_test)[i] in top_k[i]:
            correct += 1
    return correct/float(y_test.shape[0])

def evalute(model, x_test, y_test, label_embeddings_arr, k=5):
    y_test_pred = model.predict(x_test)
    sim_table, top_k_guesses = pred_top_k(y_test_pred, label_embeddings_arr, k=k)

    #Top prediction
    label_predictions = sim_table.argmax(axis=1)
    
    #Accuracy
    acc = np.sum((np.squeeze(y_test) == label_predictions)) / float(y_test.shape[0])
    top_k_acc = calc_top_k_acc(top_k_guesses, y_test)
    print("Accuracy: " + str(acc))
    print("Top " + str(k) + " Accuracy: " + str(top_k_acc))

# %%
best_model_filepath = os.path.join(save_dir, 'cifar100_%s_w2v_transfer_model.%03d.h5' % (model_type, 97))
best_model = load_model(best_model_filepath)

evalute(best_model, x_test, y_test, label_embeddings_arr)
# Out:
# Accuracy: 0.7087
# Top 5 Accuracy: 0.8137

# %%
x = np.linspace(0,99,100) 
y = np.zeros(100)
y_test_pred = model.predict(x_test)

for i in range(100):
    k = i+1
    sim_table, top_k_guesses = pred_top_k(y_test_pred, k=k)
    y[i] = calc_top_k_acc(top_k_guesses, y_test)
    
plt.plot(x,y)
plt.title("Top K Accuracy")
# Out:
# Text(0.5, 1.0, 'Top K Accuracy')

# %%
"""
model = build_model()
model.compile(loss='cosine_proximity', optimizer='adam', metrics=['mse'])
model.summary()

for i in range(epochs):
    print('Epoch: %d/%d' % (i+1, epochs))
    model.fit(x_train, y_train_embeddings,
              batch_size=batch_size,
              epochs=1,
              validation_data=(x_test, y_test_embeddings),
              shuffle=True,
              verbose=1
             )
    evalute(model, x_test, y_test, label_embeddings_arr)
    print('\n')
"""
# Out:
# "\nmodel = build_model()\nmodel.compile(loss='cosine_proximity', optimizer='adam', metrics=['mse'])\nmodel.summary()\n\nfor i in range(epochs):\n    print('Epoch: %d/%d' % (i+1, epochs))\n    model.fit(x_train, y_train_embeddings,\n              batch_size=batch_size,\n              epochs=1,\n              validation_data=(x_test, y_test_embeddings),\n              shuffle=True,\n              verbose=1\n             )\n    evalute(model, x_test, y_test, label_embeddings_arr)\n    print('\n')\n"
